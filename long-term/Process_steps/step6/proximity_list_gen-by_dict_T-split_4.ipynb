# %%
import argparse
import os
import sys
import psutil
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import math
from IPython.display import display
from multiprocessing import cpu_count,Pool 
import multiprocessing
from joblib import Parallel, delayed
from orderedset import OrderedSet
import datetime
import pickle

# %%
def print_memory_usage():
    print ("memory log:")
    process = psutil.Process(os.getpid())
    print("%5.2f GB (RSS)" % (process.memory_info().rss / 2**30))
    print("%5.2f GB (VMS)" % (process.memory_info().vms / 2**30))
    print("%5.2f GB (Used)" % (psutil.virtual_memory().used / 2**30))
    print("%5.2f GB (Available)" % (psutil.virtual_memory().available / 2**30))
    print("%5.2f GB (Total)" % (psutil.virtual_memory().total / 2**30))




def distance(data,lat,lng,idx):
    fLat = np.radians(data.LocationLat)
    fLon = np.radians(data.LocationLng)
    sLat = np.radians(lat)
    sLon = np.radians(lng)
    R = 3958.7564 #mi
    #R = 6371000.0 #meters
    #R = 6371.0 #km
    
    dLon = sLon - fLon
    dLat = sLat - fLat
    a = np.sin(dLat/2.0)**2 + (np.cos(fLat) * np.cos(sLat) * np.power(np.sin(dLon/2.0), 2))
    
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0 - a))
    data['dis2event_'+str(idx)] =  R * c
    return data

class WithExtraArgs(object):
    def __init__(self, func, **args):
        self.func = func
        self.args = args
    def __call__(self, df):
        return self.func(df, **self.args)

def parjob_long_event_group_T(data,filepath,key_ds):
    process_name = str(multiprocessing.current_process())
    id = int(process_name.split(',')[0].split('-')[1])
    print("process ",id," started")
    
    
    ds = pd.read_hdf(filepath,key=key_ds)
    print ("data set is loaded data size is ",ds.shape[0])
    traffic_events = ds[ds.Type!='W']
    
    re_list=[]
    raduis=14
    total = data.shape[0]
    counter=0
    event_duration_week_offset = 60*24*60
    print ("partial long event for process ",id," is ",data.shape[0])
    out_dict={}
    
    for idx,long_event in data.iterrows():
        #(traffic_events.City == long_event.City) &
        
        temp_df = traffic_events[  (traffic_events.State == long_event.State)  & 
                                 ((traffic_events.StartTime >= long_event.StartTime- 
                                     pd.Timedelta(event_duration_week_offset, unit='D')) & 
                                (traffic_events.EndTime <= long_event.EndTime+
                                      pd.Timedelta(event_duration_week_offset, unit='D')))]#time limit
        temp_df = distance(temp_df,long_event.LocationLat,long_event.LocationLng,idx)
        
        
        filtered_by_distance = temp_df [(temp_df['dis2event_'+str(idx)] <=raduis) & (temp_df.index != idx) ]
        #['dis2event_'+str(idx)] != 0.0)
        out_dict[idx] = filtered_by_distance.index
        #re_list.append(filtered_by_distance.index)
        
        counter+=1
        if counter%100==0:
            print ("process ", id, counter,"/",total, "long event proccesed ",datetime.datetime.now().time())        
    
    f = open('dict_files/T_'+'split_4_'+str(id)+'.pkl',"wb")
    pickle.dump(out_dict,f)
    f.close()
    return True #re_list

def applyParallel_list(pool,data, func, kwargs):
    data_split = np.array_split(data,partitions)
    data_tag =pool.map(WithExtraArgs(func, **kwargs), data_split)
    return data_tag

# %%
cores = 8#cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

# %%
import os, glob

path = "dict_files/"
dirpath = os.getcwd()
dirpath+='/'+path
for filename in glob.glob(os.path.join(dirpath, 'T_split_4*')):
    os.remove(filename)

# %%
effective_days_list=[300]
for effective_days in effective_days_list:
    long_events_ = pd.read_hdf('../../LG.h5',key='T_split_3')
    print ("long event size is ",long_events_.shape[0])
    
    subset_df = long_events_[long_events_.Type != 'W']
    print ("Traffic long events size is ",subset_df.shape[0])
    pool_t = Pool(cores)
    Traffic_list = applyParallel_list(pool_t,subset_df,parjob_long_event_group_T,{"filepath":'../../data_set_.h5','key_ds':'DS_'+str(effective_days)})
    pool_t.close()
    pool_t.join()
    print ("done with traffic set")
    print ("*"*80)
    print_memory_usage()
    
    #np.save("event_list_45_t"+str(effective_days),Traffic_list)
# Out:
# long event size is  13036
# Traffic long events size is  13036
# process  1  started
# process  2  started
# process  3  started
# process  4  started
# process  5  started
# process  6  started
# process  7  started
# process  8  started
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  7  is  1629
# partial long event for process  2  is  1630
# partial long event for process  3  is  1630
# partial long event for process  5  is  1629
# partial long event for process  1  is  1630
# partial long event for process  8  is  1629
# partial long event for process  4  is  1630
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# partial long event for process  6  is  1629
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/anaconda5/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# process  3 100 / 1630 long event proccesed  20:44:59.461587
# process  4 100 / 1630 long event proccesed  20:45:03.592547
# process  8 100 / 1629 long event proccesed  20:45:07.827758
# process  7 100 / 1629 long event proccesed  20:45:09.045047
# process  2 100 / 1630 long event proccesed  20:45:21.961530
# process  1 100 / 1630 long event proccesed  20:45:22.111807
# process  5 100 / 1629 long event proccesed  20:45:41.103300
# process  6 100 / 1629 long event proccesed  20:45:41.637536
# process  3 200 / 1630 long event proccesed  20:46:43.454665
# process  8 200 / 1629 long event proccesed  20:46:58.990556
# process  7 200 / 1629 long event proccesed  20:47:03.479473
# process  4 200 / 1630 long event proccesed  20:47:26.671563
# process  1 200 / 1630 long event proccesed  20:47:28.216371
# process  2 200 / 1630 long event proccesed  20:47:28.959076
# process  5 200 / 1629 long event proccesed  20:48:05.302472
# process  6 200 / 1629 long event proccesed  20:48:06.252480
# process  3 300 / 1630 long event proccesed  20:48:29.591124
# process  8 300 / 1629 long event proccesed  20:48:50.205389
# process  7 300 / 1629 long event proccesed  20:48:50.821452
# process  1 300 / 1630 long event proccesed  20:49:34.873960
# process  2 300 / 1630 long event proccesed  20:49:35.905972
# process  4 300 / 1630 long event proccesed  20:49:50.387376
# process  3 400 / 1630 long event proccesed  20:50:17.977639
# process  5 300 / 1629 long event proccesed  20:50:29.254079
# process  6 300 / 1629 long event proccesed  20:50:30.489765
# process  8 400 / 1629 long event proccesed  20:50:40.572409
# process  7 400 / 1629 long event proccesed  20:50:41.030566
# process  1 400 / 1630 long event proccesed  20:51:41.651995
# process  2 400 / 1630 long event proccesed  20:51:42.367986
# process  8 1200 / 1629 long event proccesed  21:04:38.865186
# process  5 900 / 1629 long event proccesed  21:04:50.955831
# process  7 1200 / 1629 long event proccesed  21:05:29.015973
# process  6 1100 / 1629 long event proccesed  21:05:48.403354
# process  8 1300 / 1629 long event proccesed  21:06:21.030646
# process  3 1300 / 1630 long event proccesed  21:06:21.162054
# process  2 1100 / 1630 long event proccesed  21:06:24.219536
# process  1 1100 / 1630 long event proccesed  21:06:25.135438
# process  4 1000 / 1630 long event proccesed  21:06:33.730216
# process  5 1000 / 1629 long event proccesed  21:07:14.634176
# process  7 1300 / 1629 long event proccesed  21:07:19.107739
# process  6 1200 / 1629 long event proccesed  21:07:42.014167
# process  8 1400 / 1629 long event proccesed  21:08:03.472188
# process  3 1400 / 1630 long event proccesed  21:08:08.215684
# process  2 1200 / 1630 long event proccesed  21:08:30.484755
# process  1 1200 / 1630 long event proccesed  21:08:31.132579
# process  4 1100 / 1630 long event proccesed  21:08:56.062417
# process  7 1400 / 1629 long event proccesed  21:09:09.900244
# process  6 1300 / 1629 long event proccesed  21:09:35.865183
# process  5 1100 / 1629 long event proccesed  21:09:37.929120
# process  8 1500 / 1629 long event proccesed  21:09:45.142966
# process  3 1500 / 1630 long event proccesed  21:09:54.949605
# process  2 1300 / 1630 long event proccesed  21:10:35.853564
# process  1 1300 / 1630 long event proccesed  21:10:36.800967
# process  7 1500 / 1629 long event proccesed  21:11:00.085921
# process  4 1200 / 1630 long event proccesed  21:11:19.489178
# process  8 1600 / 1629 long event proccesed  21:11:26.184141
# process  6 1400 / 1629 long event proccesed  21:11:30.036002
# process  3 1600 / 1630 long event proccesed  21:11:42.040047
# process  5 1200 / 1629 long event proccesed  21:12:00.706476
# process  2 1400 / 1630 long event proccesed  21:12:40.326872
# process  1 1400 / 1630 long event proccesed  21:12:41.753554
# process  7 1600 / 1629 long event proccesed  21:12:49.531416
# process  6 1500 / 1629 long event proccesed  21:13:23.353396
# process  4 1300 / 1630 long event proccesed  21:13:41.340609
# process  5 1300 / 1629 long event proccesed  21:14:20.670984
# process  2 1500 / 1630 long event proccesed  21:14:41.600706
# process  1 1500 / 1630 long event proccesed  21:14:43.345053
# process  6 1600 / 1629 long event proccesed  21:15:11.448677
# process  4 1400 / 1630 long event proccesed  21:16:08.461157
# process  2 1600 / 1630 long event proccesed  21:16:18.458824
# process  5 1400 / 1629 long event proccesed  21:16:36.992300
# process  1 1600 / 1630 long event proccesed  21:16:41.696587
# process  4 1500 / 1630 long event proccesed  21:18:22.899638
# process  5 1500 / 1629 long event proccesed  21:18:48.049152
# process  4 1600 / 1630 long event proccesed  21:20:32.927334
# process  5 1600 / 1629 long event proccesed  21:20:57.799177
# done with traffic set
# ********************************************************************************
# memory log:
#  0.11 GB (RSS)
#  1.08 GB (VMS)
#  5.55 GB (Used)
# 119.50 GB (Available)
# 125.81 GB (Total)
