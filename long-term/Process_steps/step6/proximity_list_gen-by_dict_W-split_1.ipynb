# %%
import argparse
import os
import sys
import psutil
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import math
from IPython.display import display
from multiprocessing import cpu_count,Pool 
import multiprocessing
from joblib import Parallel, delayed
from orderedset import OrderedSet
import datetime
import pickle

# %%
def print_memory_usage():
    print ("memory log:")
    process = psutil.Process(os.getpid())
    print("%5.2f GB (RSS)" % (process.memory_info().rss / 2**30))
    print("%5.2f GB (VMS)" % (process.memory_info().vms / 2**30))
    print("%5.2f GB (Used)" % (psutil.virtual_memory().used / 2**30))
    print("%5.2f GB (Available)" % (psutil.virtual_memory().available / 2**30))
    print("%5.2f GB (Total)" % (psutil.virtual_memory().total / 2**30))




def distance(data,lat,lng,idx):
    fLat = np.radians(data.LocationLat)
    fLon = np.radians(data.LocationLng)
    sLat = np.radians(lat)
    sLon = np.radians(lng)
    R = 3958.7564 #mi
    #R = 6371000.0 #meters
    #R = 6371.0 #km
    
    dLon = sLon - fLon
    dLat = sLat - fLat
    a = np.sin(dLat/2.0)**2 + (np.cos(fLat) * np.cos(sLat) * np.power(np.sin(dLon/2.0), 2))
    
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0 - a))
    data['dis2event_'+str(idx)] =  R * c
    return data

class WithExtraArgs(object):
    def __init__(self, func, **args):
        self.func = func
        self.args = args
    def __call__(self, df):
        return self.func(df, **self.args)
def parjob_long_event_group_W(data,filepath,key_ds):
    process_name = str(multiprocessing.current_process())
    id = int(process_name.split(',')[0].split('-')[1])
    print("process ",id," started")
    
    ds = pd.read_hdf(filepath,key=key_ds)
    print ("data set is loaded data size is ",ds.shape[0])
    traffic_events = ds[ds.Type!='W']
    re_list=[]
    total = data.shape[0]
    counter=0
    event_duration_week_offset = 60*24*60 
    print ("partial long event for process ",id," is ",data.shape[0])
    
    out_dict={}
    for idx,long_event in data.iterrows():
        temp_df = traffic_events[(traffic_events.AirportCode == long_event.AirportCode) & 
                                 ((traffic_events.StartTime >= long_event.StartTime- 
                                     pd.Timedelta(event_duration_week_offset, unit='D')) & 
                                (traffic_events.EndTime <= long_event.EndTime+
                                      pd.Timedelta(event_duration_week_offset, unit='D')))]

        out_dict[idx] = temp_df.index
        counter+=1
        if counter%100==0:
            print ("process ",id, counter,"/",total, "long event proccesed ", datetime.datetime.now().time())
    f = open('dict_files/W_'+'split_1_'+str(id)+'.pkl',"wb")
    pickle.dump(out_dict,f)
    f.close()
    return True #re_list
    
def applyParallel_list(pool,data, func, kwargs):
    data_split = np.array_split(data,partitions)
    data_tag =pool.map(WithExtraArgs(func, **kwargs), data_split)
    return data_tag

# %%
cores = 8#cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

# %%
import os, glob

path = "dict_files/"
dirpath = os.getcwd()
dirpath+='/'+path
for filename in glob.glob(os.path.join(dirpath, 'W_split_1*')):
    os.remove(filename)

# %%
#effective_days_list=[900,800,700,600]#,500,400,300]
#effective_days_list=[500,400]#,

    
effective_days_list=[300]
for effective_days in effective_days_list:
    print ("generating long event list for ",effective_days)
    long_events_ = pd.read_hdf('../../LG.h5',key='W_split_0')
    print ("long event size is ",long_events_.shape[0])
    
    subset_df =  long_events_[long_events_.Type == 'W']
    print ("weather long events size is ",subset_df.shape[0])
    
    pool_w = Pool(cores)
    Weather_list = applyParallel_list(pool_w,subset_df,parjob_long_event_group_W,{'filepath':'../../data_set_.h5','key_ds':'DS_'+str(effective_days)})
    pool_w.close()
    pool_w.join()
    print ("done with weather set")
    print ("*"*80)
    print_memory_usage()
    #np.save("event_list_45_w"+str(effective_days),Weather_list)
# Out:
# generating long event list for  300
# long event size is  24024
# weather long events size is  24024
# process  1  started
# process  2  started
# process  3  started
# process  4  started
# process  5  started
# process  6  started
# process  7  started
# process  8  started
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  3  is  3003
# partial long event for process  5  is  3003
# partial long event for process  8  is  3003
# partial long event for process  6  is  3003
# partial long event for process  7  is  3003
# partial long event for process  2  is  3003
# partial long event for process  1  is  3003
# partial long event for process  4  is  3003
# process  7 100 / 3003 long event proccesed  20:46:29.355811
# process  6 100 / 3003 long event proccesed  20:46:29.538949
# process  5 100 / 3003 long event proccesed  20:46:29.955153
# process  1 100 / 3003 long event proccesed  20:46:30.201953
# process  8 100 / 3003 long event proccesed  20:46:30.716529
# process  3 100 / 3003 long event proccesed  20:46:30.840501
# process  4 100 / 3003 long event proccesed  20:46:31.807979
# process  2 100 / 3003 long event proccesed  20:46:32.224494
# process  7 200 / 3003 long event proccesed  20:48:09.402258
# process  6 200 / 3003 long event proccesed  20:48:09.683178
# process  5 200 / 3003 long event proccesed  20:48:09.868371
# process  1 200 / 3003 long event proccesed  20:48:10.414747
# process  8 200 / 3003 long event proccesed  20:48:12.825313
# process  3 200 / 3003 long event proccesed  20:48:13.429029
# process  4 200 / 3003 long event proccesed  20:48:13.624385
# process  2 200 / 3003 long event proccesed  20:48:14.553695
# process  7 300 / 3003 long event proccesed  20:49:49.779674
# process  5 300 / 3003 long event proccesed  20:49:49.936208
# process  6 300 / 3003 long event proccesed  20:49:49.969630
# process  1 300 / 3003 long event proccesed  20:49:50.482385
# process  8 300 / 3003 long event proccesed  20:49:54.968627
# process  4 300 / 3003 long event proccesed  20:49:55.370591
# process  3 300 / 3003 long event proccesed  20:49:56.412023
# process  2 300 / 3003 long event proccesed  20:49:57.648830
# process  7 400 / 3003 long event proccesed  20:51:29.730793
# process  6 400 / 3003 long event proccesed  20:51:30.369625
# process  1 400 / 3003 long event proccesed  20:51:30.453153
# process  5 400 / 3003 long event proccesed  20:51:30.475633
# process  4 400 / 3003 long event proccesed  20:51:36.967258
# process  8 400 / 3003 long event proccesed  20:51:36.989740
# process  3 400 / 3003 long event proccesed  20:51:39.116565
# process  2 400 / 3003 long event proccesed  20:51:40.025523
# process  7 500 / 3003 long event proccesed  20:53:09.791997
# process  1 500 / 3003 long event proccesed  20:53:10.609254
# process  5 500 / 3003 long event proccesed  20:53:11.061785
# process  3 2400 / 3003 long event proccesed  21:25:34.567595
# process  1 2500 / 3003 long event proccesed  21:26:48.130168
# process  7 2500 / 3003 long event proccesed  21:26:49.085735
# process  6 2500 / 3003 long event proccesed  21:26:53.491743
# process  5 2500 / 3003 long event proccesed  21:26:54.919725
# process  8 2500 / 3003 long event proccesed  21:27:03.867660
# process  4 2500 / 3003 long event proccesed  21:27:04.921501
# process  2 2500 / 3003 long event proccesed  21:27:06.503851
# process  3 2500 / 3003 long event proccesed  21:27:15.906026
# process  1 2600 / 3003 long event proccesed  21:28:30.058252
# process  7 2600 / 3003 long event proccesed  21:28:31.363916
# process  6 2600 / 3003 long event proccesed  21:28:35.389112
# process  5 2600 / 3003 long event proccesed  21:28:37.282036
# process  8 2600 / 3003 long event proccesed  21:28:44.063845
# process  4 2600 / 3003 long event proccesed  21:28:46.148493
# process  2 2600 / 3003 long event proccesed  21:28:46.512378
# process  3 2600 / 3003 long event proccesed  21:28:56.971752
# process  1 2700 / 3003 long event proccesed  21:30:11.554634
# process  7 2700 / 3003 long event proccesed  21:30:13.187613
# process  6 2700 / 3003 long event proccesed  21:30:16.926487
# process  5 2700 / 3003 long event proccesed  21:30:19.270660
# process  8 2700 / 3003 long event proccesed  21:30:24.713926
# process  2 2700 / 3003 long event proccesed  21:30:26.706633
# process  4 2700 / 3003 long event proccesed  21:30:27.253976
# process  3 2700 / 3003 long event proccesed  21:30:37.974473
# process  1 2800 / 3003 long event proccesed  21:31:53.320302
# process  7 2800 / 3003 long event proccesed  21:31:55.305974
# process  6 2800 / 3003 long event proccesed  21:31:58.636033
# process  5 2800 / 3003 long event proccesed  21:32:01.542158
# process  8 2800 / 3003 long event proccesed  21:32:04.793545
# process  2 2800 / 3003 long event proccesed  21:32:06.826114
# process  4 2800 / 3003 long event proccesed  21:32:08.535729
# process  3 2800 / 3003 long event proccesed  21:32:18.968977
# process  1 2900 / 3003 long event proccesed  21:33:35.862882
# process  7 2900 / 3003 long event proccesed  21:33:37.195242
# process  6 2900 / 3003 long event proccesed  21:33:40.582748
# process  5 2900 / 3003 long event proccesed  21:33:43.480680
# process  8 2900 / 3003 long event proccesed  21:33:44.901921
# process  2 2900 / 3003 long event proccesed  21:33:47.515806
# process  4 2900 / 3003 long event proccesed  21:33:49.613606
# process  3 2900 / 3003 long event proccesed  21:33:59.396509
# process  1 3000 / 3003 long event proccesed  21:35:18.187804
# process  7 3000 / 3003 long event proccesed  21:35:18.879947
# process  6 3000 / 3003 long event proccesed  21:35:22.406035
# process  8 3000 / 3003 long event proccesed  21:35:24.865939
# process  5 3000 / 3003 long event proccesed  21:35:25.417584
# process  2 3000 / 3003 long event proccesed  21:35:27.571762
# process  4 3000 / 3003 long event proccesed  21:35:31.269961
# process  3 3000 / 3003 long event proccesed  21:35:39.980556
# done with weather set
# ********************************************************************************
# memory log:
#  0.11 GB (RSS)
#  1.08 GB (VMS)
#  3.20 GB (Used)
# 121.95 GB (Available)
# 125.81 GB (Total)
