# %%
import argparse
import os
import sys
import psutil
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import math
from IPython.display import display
from multiprocessing import cpu_count,Pool 
import multiprocessing
from joblib import Parallel, delayed
from orderedset import OrderedSet
import datetime
import pickle

# %%
def print_memory_usage():
    print ("memory log:")
    process = psutil.Process(os.getpid())
    print("%5.2f GB (RSS)" % (process.memory_info().rss / 2**30))
    print("%5.2f GB (VMS)" % (process.memory_info().vms / 2**30))
    print("%5.2f GB (Used)" % (psutil.virtual_memory().used / 2**30))
    print("%5.2f GB (Available)" % (psutil.virtual_memory().available / 2**30))
    print("%5.2f GB (Total)" % (psutil.virtual_memory().total / 2**30))




def distance(data,lat,lng,idx):
    fLat = np.radians(data.LocationLat)
    fLon = np.radians(data.LocationLng)
    sLat = np.radians(lat)
    sLon = np.radians(lng)
    R = 3958.7564 #mi
    #R = 6371000.0 #meters
    #R = 6371.0 #km
    
    dLon = sLon - fLon
    dLat = sLat - fLat
    a = np.sin(dLat/2.0)**2 + (np.cos(fLat) * np.cos(sLat) * np.power(np.sin(dLon/2.0), 2))
    
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0 - a))
    data['dis2event_'+str(idx)] =  R * c
    return data

class WithExtraArgs(object):
    def __init__(self, func, **args):
        self.func = func
        self.args = args
    def __call__(self, df):
        return self.func(df, **self.args)
def parjob_long_event_group_W(data,filepath,key_ds):
    process_name = str(multiprocessing.current_process())
    id = int(process_name.split(',')[0].split('-')[1])
    print("process ",id," started")
    
    ds = pd.read_hdf(filepath,key=key_ds)
    print ("data set is loaded data size is ",ds.shape[0])
    traffic_events = ds[ds.Type!='W']
    re_list=[]
    total = data.shape[0]
    counter=0
    event_duration_week_offset = 60*24*60 
    print ("partial long event for process ",id," is ",data.shape[0])
    
    out_dict={}
    for idx,long_event in data.iterrows():
        temp_df = traffic_events[(traffic_events.AirportCode == long_event.AirportCode) & 
                                 ((traffic_events.StartTime >= long_event.StartTime- 
                                     pd.Timedelta(event_duration_week_offset, unit='D')) & 
                                (traffic_events.EndTime <= long_event.EndTime+
                                      pd.Timedelta(event_duration_week_offset, unit='D')))]

        out_dict[idx] = temp_df.index
        counter+=1
        if counter%100==0:
            print ("process ",id, counter,"/",total, "long event proccesed ", datetime.datetime.now().time())
    f = open('dict_files/W_'+'split_2_'+str(id)+'.pkl',"wb")
    pickle.dump(out_dict,f)
    f.close()
    return True #re_list
    
def applyParallel_list(pool,data, func, kwargs):
    data_split = np.array_split(data,partitions)
    data_tag =pool.map(WithExtraArgs(func, **kwargs), data_split)
    return data_tag

# %%
cores = 8#cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

# %%
import os, glob

path = "dict_files/"
dirpath = os.getcwd()
dirpath+='/'+path
for filename in glob.glob(os.path.join(dirpath, 'W_split_2*')):
    os.remove(filename)

# %%
#effective_days_list=[900,800,700,600]#,500,400,300]
#effective_days_list=[500,400]#,

    
effective_days_list=[300]
for effective_days in effective_days_list:
    print ("generating long event list for ",effective_days)
    long_events_ = pd.read_hdf('../../LG.h5',key='W_split_1')
    print ("long event size is ",long_events_.shape[0])
    
    subset_df =  long_events_[long_events_.Type == 'W']
    print ("weather long events size is ",subset_df.shape[0])
    
    pool_w = Pool(cores)
    Weather_list = applyParallel_list(pool_w,subset_df,parjob_long_event_group_W,{'filepath':'../../data_set_.h5','key_ds':'DS_'+str(effective_days)})
    pool_w.close()
    pool_w.join()
    print ("done with weather set")
    print ("*"*80)
    print_memory_usage()
    #np.save("event_list_45_w"+str(effective_days),Weather_list)
# Out:
# generating long event list for  300
# long event size is  24023
# weather long events size is  24023
# process  1  started
# process  2  started
# process  3  started
# process  4  started
# process  5  started
# process  6  started
# process  7  started
# process  8  started
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  3  is  3003
# partial long event for process  2  is  3003
# partial long event for process  5  is  3003
# partial long event for process  8  is  3002
# partial long event for process  1  is  3003
# partial long event for process  7  is  3003
# partial long event for process  6  is  3003
# partial long event for process  4  is  3003
# process  2 100 / 3003 long event proccesed  20:50:28.815601
# process  8 100 / 3002 long event proccesed  20:50:29.028091
# process  1 100 / 3003 long event proccesed  20:50:29.641125
# process  7 100 / 3003 long event proccesed  20:50:29.912174
# process  5 100 / 3003 long event proccesed  20:50:30.672293
# process  3 100 / 3003 long event proccesed  20:50:30.794258
# process  6 100 / 3003 long event proccesed  20:50:31.641171
# process  4 100 / 3003 long event proccesed  20:50:32.103423
# process  2 200 / 3003 long event proccesed  20:52:06.531708
# process  8 200 / 3002 long event proccesed  20:52:06.688761
# process  1 200 / 3003 long event proccesed  20:52:07.204923
# process  7 200 / 3003 long event proccesed  20:52:07.750026
# process  5 200 / 3003 long event proccesed  20:52:10.244985
# process  3 200 / 3003 long event proccesed  20:52:10.967279
# process  6 200 / 3003 long event proccesed  20:52:11.470191
# process  4 200 / 3003 long event proccesed  20:52:11.721224
# process  2 300 / 3003 long event proccesed  20:53:44.498512
# process  8 300 / 3002 long event proccesed  20:53:44.938093
# process  1 300 / 3003 long event proccesed  20:53:44.950582
# process  7 300 / 3003 long event proccesed  20:53:45.705732
# process  5 300 / 3003 long event proccesed  20:53:49.736445
# process  3 300 / 3003 long event proccesed  20:53:50.923664
# process  6 300 / 3003 long event proccesed  20:53:51.032303
# process  4 300 / 3003 long event proccesed  20:53:51.242346
# process  2 400 / 3003 long event proccesed  20:55:22.181541
# process  1 400 / 3003 long event proccesed  20:55:22.819315
# process  8 400 / 3002 long event proccesed  20:55:23.072549
# process  7 400 / 3003 long event proccesed  20:55:23.478318
# process  5 400 / 3003 long event proccesed  20:55:29.381948
# process  4 400 / 3003 long event proccesed  20:55:31.350684
# process  3 400 / 3003 long event proccesed  20:55:31.390152
# process  6 400 / 3003 long event proccesed  20:55:31.432806
# process  2 500 / 3003 long event proccesed  20:57:00.091511
# process  1 500 / 3003 long event proccesed  20:57:00.598427
# process  7 500 / 3003 long event proccesed  20:57:01.151498
# process  8 500 / 3002 long event proccesed  20:57:01.228795
# process  1 2500 / 3003 long event proccesed  21:29:57.217439
# process  7 2500 / 3003 long event proccesed  21:29:59.016162
# process  5 2500 / 3003 long event proccesed  21:29:59.438016
# process  6 2500 / 3003 long event proccesed  21:30:01.781060
# process  2 2500 / 3003 long event proccesed  21:30:02.496987
# process  8 2500 / 3002 long event proccesed  21:30:02.979551
# process  4 2500 / 3003 long event proccesed  21:30:03.828607
# process  3 2500 / 3003 long event proccesed  21:30:06.592231
# process  1 2600 / 3003 long event proccesed  21:31:36.585532
# process  5 2600 / 3003 long event proccesed  21:31:37.338025
# process  7 2600 / 3003 long event proccesed  21:31:38.773943
# process  6 2600 / 3003 long event proccesed  21:31:40.004961
# process  2 2600 / 3003 long event proccesed  21:31:42.135234
# process  4 2600 / 3003 long event proccesed  21:31:42.339197
# process  8 2600 / 3002 long event proccesed  21:31:42.568032
# process  3 2600 / 3003 long event proccesed  21:31:44.801099
# process  5 2700 / 3003 long event proccesed  21:33:15.217093
# process  1 2700 / 3003 long event proccesed  21:33:15.822650
# process  6 2700 / 3003 long event proccesed  21:33:17.913294
# process  7 2700 / 3003 long event proccesed  21:33:18.020819
# process  4 2700 / 3003 long event proccesed  21:33:20.549245
# process  2 2700 / 3003 long event proccesed  21:33:21.750169
# process  8 2700 / 3002 long event proccesed  21:33:21.995693
# process  3 2700 / 3003 long event proccesed  21:33:22.733424
# process  5 2800 / 3003 long event proccesed  21:34:53.090082
# process  1 2800 / 3003 long event proccesed  21:34:54.722456
# process  6 2800 / 3003 long event proccesed  21:34:55.816480
# process  7 2800 / 3003 long event proccesed  21:34:57.529676
# process  4 2800 / 3003 long event proccesed  21:34:58.502224
# process  3 2800 / 3003 long event proccesed  21:35:00.962883
# process  8 2800 / 3002 long event proccesed  21:35:01.567143
# process  2 2800 / 3003 long event proccesed  21:35:01.740834
# process  5 2900 / 3003 long event proccesed  21:36:31.296823
# process  6 2900 / 3003 long event proccesed  21:36:33.780666
# process  1 2900 / 3003 long event proccesed  21:36:34.206797
# process  4 2900 / 3003 long event proccesed  21:36:36.692269
# process  7 2900 / 3003 long event proccesed  21:36:37.360926
# process  3 2900 / 3003 long event proccesed  21:36:39.179280
# process  8 2900 / 3002 long event proccesed  21:36:41.315002
# process  2 2900 / 3003 long event proccesed  21:36:41.487708
# process  5 3000 / 3003 long event proccesed  21:38:09.539832
# process  6 3000 / 3003 long event proccesed  21:38:11.949115
# process  1 3000 / 3003 long event proccesed  21:38:13.363290
# process  4 3000 / 3003 long event proccesed  21:38:14.960183
# process  7 3000 / 3003 long event proccesed  21:38:17.014814
# process  3 3000 / 3003 long event proccesed  21:38:17.482417
# process  8 3000 / 3002 long event proccesed  21:38:20.944586
# process  2 3000 / 3003 long event proccesed  21:38:21.283419
# done with weather set
# ********************************************************************************
# memory log:
#  0.11 GB (RSS)
#  1.08 GB (VMS)
#  3.27 GB (Used)
# 121.80 GB (Available)
# 125.81 GB (Total)
