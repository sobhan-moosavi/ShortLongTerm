# %%
import argparse
import os
import sys
import psutil
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import math
from IPython.display import display
from multiprocessing import cpu_count,Pool 
import multiprocessing
from joblib import Parallel, delayed
from orderedset import OrderedSet
import datetime
import pickle

# %%
def print_memory_usage():
    print ("memory log:")
    process = psutil.Process(os.getpid())
    print("%5.2f GB (RSS)" % (process.memory_info().rss / 2**30))
    print("%5.2f GB (VMS)" % (process.memory_info().vms / 2**30))
    print("%5.2f GB (Used)" % (psutil.virtual_memory().used / 2**30))
    print("%5.2f GB (Available)" % (psutil.virtual_memory().available / 2**30))
    print("%5.2f GB (Total)" % (psutil.virtual_memory().total / 2**30))




def distance(data,lat,lng,idx):
    fLat = np.radians(data.LocationLat)
    fLon = np.radians(data.LocationLng)
    sLat = np.radians(lat)
    sLon = np.radians(lng)
    R = 3958.7564 #mi
    #R = 6371000.0 #meters
    #R = 6371.0 #km
    
    dLon = sLon - fLon
    dLat = sLat - fLat
    a = np.sin(dLat/2.0)**2 + (np.cos(fLat) * np.cos(sLat) * np.power(np.sin(dLon/2.0), 2))
    
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0 - a))
    data['dis2event_'+str(idx)] =  R * c
    return data

class WithExtraArgs(object):
    def __init__(self, func, **args):
        self.func = func
        self.args = args
    def __call__(self, df):
        return self.func(df, **self.args)
def parjob_long_event_group_W(data,filepath,key_ds):
    process_name = str(multiprocessing.current_process())
    id = int(process_name.split(',')[0].split('-')[1])
    print("process ",id," started")
    
    ds = pd.read_hdf(filepath,key=key_ds)
    print ("data set is loaded data size is ",ds.shape[0])
    traffic_events = ds[ds.Type!='W']
    re_list=[]
    total = data.shape[0]
    counter=0
    event_duration_week_offset = 60*24*60 
    print ("partial long event for process ",id," is ",data.shape[0])
    
    out_dict={}
    for idx,long_event in data.iterrows():
        temp_df = traffic_events[(traffic_events.AirportCode == long_event.AirportCode) & 
                                 ((traffic_events.StartTime >= long_event.StartTime- 
                                     pd.Timedelta(event_duration_week_offset, unit='D')) & 
                                (traffic_events.EndTime <= long_event.EndTime+
                                      pd.Timedelta(event_duration_week_offset, unit='D')))]

        out_dict[idx] = temp_df.index
        counter+=1
        if counter%100==0:
            print ("process ",id, counter,"/",total, "long event proccesed ", datetime.datetime.now().time())
    f = open('dict_files/W_'+'split_3_'+str(id)+'.pkl',"wb")
    pickle.dump(out_dict,f)
    f.close()
    return True #re_list
    
def applyParallel_list(pool,data, func, kwargs):
    data_split = np.array_split(data,partitions)
    data_tag =pool.map(WithExtraArgs(func, **kwargs), data_split)
    return data_tag

# %%
cores = 8#cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

# %%
import os, glob

path = "dict_files/"
dirpath = os.getcwd()
dirpath+='/'+path
for filename in glob.glob(os.path.join(dirpath, 'W_split_3*')):
    os.remove(filename)

# %%
#effective_days_list=[900,800,700,600]#,500,400,300]
#effective_days_list=[500,400]#,

    
effective_days_list=[300]
for effective_days in effective_days_list:
    print ("generating long event list for ",effective_days)
    long_events_ = pd.read_hdf('../../LG.h5',key='W_split_2')
    print ("long event size is ",long_events_.shape[0])
    
    subset_df =  long_events_[long_events_.Type == 'W']
    print ("weather long events size is ",subset_df.shape[0])
    
    pool_w = Pool(cores)
    Weather_list = applyParallel_list(pool_w,subset_df,parjob_long_event_group_W,{'filepath':'../../data_set_.h5','key_ds':'DS_'+str(effective_days)})
    pool_w.close()
    pool_w.join()
    print ("done with weather set")
    print ("*"*80)
    print_memory_usage()
    #np.save("event_list_45_w"+str(effective_days),Weather_list)
# Out:
# generating long event list for  300
# long event size is  24023
# weather long events size is  24023
# process  1  started
# process  2  started
# process  3  started
# process  4  started
# process  5  started
# process  6  started
# process  7  started
# process  8  started
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  4  is  3003
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  6  is  3003
# partial long event for process  3  is  3003
# partial long event for process  5  is  3003
# partial long event for process  1  is  3003
# partial long event for process  2  is  3003
# partial long event for process  8  is  3002
# partial long event for process  7  is  3003
# process  4 100 / 3003 long event proccesed  20:51:11.451466
# process  3 100 / 3003 long event proccesed  20:51:12.448185
# process  6 100 / 3003 long event proccesed  20:51:14.003696
# process  1 100 / 3003 long event proccesed  20:51:14.352966
# process  5 100 / 3003 long event proccesed  20:51:14.423215
# process  2 100 / 3003 long event proccesed  20:51:14.992339
# process  8 100 / 3002 long event proccesed  20:51:15.809525
# process  7 100 / 3003 long event proccesed  20:51:16.508471
# process  4 200 / 3003 long event proccesed  20:52:49.350226
# process  3 200 / 3003 long event proccesed  20:52:49.751147
# process  1 200 / 3003 long event proccesed  20:52:52.075820
# process  5 200 / 3003 long event proccesed  20:52:52.202462
# process  6 200 / 3003 long event proccesed  20:52:52.936040
# process  2 200 / 3003 long event proccesed  20:52:53.432066
# process  8 200 / 3002 long event proccesed  20:52:54.509998
# process  7 200 / 3003 long event proccesed  20:52:55.239121
# process  3 300 / 3003 long event proccesed  20:54:27.068967
# process  4 300 / 3003 long event proccesed  20:54:27.150528
# process  1 300 / 3003 long event proccesed  20:54:29.890861
# process  5 300 / 3003 long event proccesed  20:54:30.040845
# process  6 300 / 3003 long event proccesed  20:54:31.638282
# process  2 300 / 3003 long event proccesed  20:54:31.917030
# process  8 300 / 3002 long event proccesed  20:54:32.993701
# process  7 300 / 3003 long event proccesed  20:54:33.869265
# process  3 400 / 3003 long event proccesed  20:56:04.721892
# process  4 400 / 3003 long event proccesed  20:56:04.864756
# process  1 400 / 3003 long event proccesed  20:56:07.357236
# process  5 400 / 3003 long event proccesed  20:56:07.673040
# process  2 400 / 3003 long event proccesed  20:56:10.352341
# process  6 400 / 3003 long event proccesed  20:56:10.726270
# process  8 400 / 3002 long event proccesed  20:56:11.814909
# process  7 400 / 3003 long event proccesed  20:56:12.781835
# process  3 500 / 3003 long event proccesed  20:57:41.902911
# process  4 500 / 3003 long event proccesed  20:57:42.347458
# process  1 500 / 3003 long event proccesed  20:57:44.611519
# process  5 500 / 3003 long event proccesed  20:57:45.026067
# process  2 500 / 3003 long event proccesed  20:57:48.897203
# process  6 500 / 3003 long event proccesed  20:57:50.165723
# process  8 500 / 3002 long event proccesed  20:57:51.108206
# process  7 500 / 3003 long event proccesed  20:57:51.706308
# process  3 600 / 3003 long event proccesed  20:59:19.297616
# process  4 600 / 3003 long event proccesed  20:59:20.527384
# process  1 600 / 3003 long event proccesed  20:59:22.318779
# process  5 600 / 3003 long event proccesed  20:59:22.334089
# process  2 600 / 3003 long event proccesed  20:59:27.112762
# process  6 600 / 3003 long event proccesed  20:59:28.824755
# process  8 600 / 3002 long event proccesed  20:59:29.598816
# process  7 600 / 3003 long event proccesed  20:59:30.094886
# process  3 700 / 3003 long event proccesed  21:00:56.261364
# process  4 700 / 3003 long event proccesed  21:00:58.558651
# process  5 700 / 3003 long event proccesed  21:00:59.779298
# process  1 700 / 3003 long event proccesed  21:00:59.982645
# process  2 700 / 3003 long event proccesed  21:01:05.454354
# process  6 700 / 3003 long event proccesed  21:01:07.731621
# process  8 700 / 3002 long event proccesed  21:01:08.123416
# process  7 700 / 3003 long event proccesed  21:01:08.948272
# process  3 800 / 3003 long event proccesed  21:02:33.503103
# process  4 800 / 3003 long event proccesed  21:02:36.428157
# process  1 800 / 3003 long event proccesed  21:02:37.707245
# process  5 800 / 3003 long event proccesed  21:02:37.818388
# process  2 800 / 3003 long event proccesed  21:02:43.916562
# process  6 800 / 3003 long event proccesed  21:02:46.728983
# process  8 800 / 3002 long event proccesed  21:02:46.876622
# process  7 800 / 3003 long event proccesed  21:02:47.759405
# process  3 900 / 3003 long event proccesed  21:04:10.856579
# process  4 900 / 3003 long event proccesed  21:04:14.785209
# process  1 900 / 3003 long event proccesed  21:04:15.309266
# process  5 900 / 3003 long event proccesed  21:04:15.766093
# process  2 900 / 3003 long event proccesed  21:04:22.423961
# process  8 900 / 3002 long event proccesed  21:04:25.887216
# process  7 900 / 3003 long event proccesed  21:04:26.193302
# process  6 900 / 3003 long event proccesed  21:04:26.202794
# process  3 1000 / 3003 long event proccesed  21:05:48.189406
# process  1 1000 / 3003 long event proccesed  21:05:53.067055
# process  4 1000 / 3003 long event proccesed  21:05:53.226291
# process  5 1000 / 3003 long event proccesed  21:05:53.887147
# process  2 1000 / 3003 long event proccesed  21:06:00.857026
# process  7 1000 / 3003 long event proccesed  21:06:04.860567
# process  8 1000 / 3002 long event proccesed  21:06:04.874860
# process  6 1000 / 3003 long event proccesed  21:06:05.657431
# process  3 1100 / 3003 long event proccesed  21:07:25.606612
# process  1 1100 / 3003 long event proccesed  21:07:30.668907
# process  4 1100 / 3003 long event proccesed  21:07:31.107476
# process  5 1100 / 3003 long event proccesed  21:07:32.039588
# process  2 1100 / 3003 long event proccesed  21:07:39.076510
# process  7 1100 / 3003 long event proccesed  21:07:43.174366
# process  8 1100 / 3002 long event proccesed  21:07:43.570340
# process  6 1100 / 3003 long event proccesed  21:07:44.473245
# process  3 2500 / 3003 long event proccesed  21:30:08.392856
# process  1 2500 / 3003 long event proccesed  21:30:15.254613
# process  5 2500 / 3003 long event proccesed  21:30:22.988970
# process  4 2500 / 3003 long event proccesed  21:30:22.995422
# process  2 2500 / 3003 long event proccesed  21:30:35.903089
# process  7 2500 / 3003 long event proccesed  21:30:41.709882
# process  6 2500 / 3003 long event proccesed  21:30:48.033712
# process  8 2500 / 3002 long event proccesed  21:30:48.750317
# process  3 2600 / 3003 long event proccesed  21:31:46.448470
# process  1 2600 / 3003 long event proccesed  21:31:52.923618
# process  5 2600 / 3003 long event proccesed  21:32:01.142081
# process  4 2600 / 3003 long event proccesed  21:32:01.724354
# process  2 2600 / 3003 long event proccesed  21:32:14.042394
# process  7 2600 / 3003 long event proccesed  21:32:20.476337
# process  6 2600 / 3003 long event proccesed  21:32:26.795456
# process  8 2600 / 3002 long event proccesed  21:32:27.713545
# process  3 2700 / 3003 long event proccesed  21:33:24.364494
# process  1 2700 / 3003 long event proccesed  21:33:30.387799
# process  5 2700 / 3003 long event proccesed  21:33:38.858213
# process  4 2700 / 3003 long event proccesed  21:33:40.266412
# process  2 2700 / 3003 long event proccesed  21:33:52.333921
# process  7 2700 / 3003 long event proccesed  21:33:58.906273
# process  6 2700 / 3003 long event proccesed  21:34:05.473442
# process  8 2700 / 3002 long event proccesed  21:34:06.801645
# process  3 2800 / 3003 long event proccesed  21:35:02.096507
# process  1 2800 / 3003 long event proccesed  21:35:07.898548
# process  5 2800 / 3003 long event proccesed  21:35:16.275077
# process  4 2800 / 3003 long event proccesed  21:35:18.276308
# process  2 2800 / 3003 long event proccesed  21:35:30.953770
# process  7 2800 / 3003 long event proccesed  21:35:37.988433
# process  6 2800 / 3003 long event proccesed  21:35:43.919239
# process  8 2800 / 3002 long event proccesed  21:35:45.630963
# process  3 2900 / 3003 long event proccesed  21:36:39.828610
# process  1 2900 / 3003 long event proccesed  21:36:45.380970
# process  5 2900 / 3003 long event proccesed  21:36:53.735003
# process  4 2900 / 3003 long event proccesed  21:36:56.603806
# process  2 2900 / 3003 long event proccesed  21:37:09.533391
# process  7 2900 / 3003 long event proccesed  21:37:16.813307
# process  6 2900 / 3003 long event proccesed  21:37:22.723626
# process  8 2900 / 3002 long event proccesed  21:37:24.558002
# process  3 3000 / 3003 long event proccesed  21:38:17.339973
# process  1 3000 / 3003 long event proccesed  21:38:22.788446
# process  5 3000 / 3003 long event proccesed  21:38:31.145644
# process  4 3000 / 3003 long event proccesed  21:38:34.030027
# process  2 3000 / 3003 long event proccesed  21:38:46.996378
# process  7 3000 / 3003 long event proccesed  21:38:55.078846
# process  6 3000 / 3003 long event proccesed  21:39:00.528139
# process  8 3000 / 3002 long event proccesed  21:39:01.422375
# done with weather set
# ********************************************************************************
# memory log:
#  0.11 GB (RSS)
#  1.08 GB (VMS)
#  3.55 GB (Used)
# 121.38 GB (Available)
# 125.81 GB (Total)
