# %%
import argparse
import os
import sys
import psutil
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import math
from IPython.display import display
from multiprocessing import cpu_count,Pool 
import multiprocessing
from joblib import Parallel, delayed
from orderedset import OrderedSet
import datetime
import pickle

# %%
def print_memory_usage():
    print ("memory log:")
    process = psutil.Process(os.getpid())
    print("%5.2f GB (RSS)" % (process.memory_info().rss / 2**30))
    print("%5.2f GB (VMS)" % (process.memory_info().vms / 2**30))
    print("%5.2f GB (Used)" % (psutil.virtual_memory().used / 2**30))
    print("%5.2f GB (Available)" % (psutil.virtual_memory().available / 2**30))
    print("%5.2f GB (Total)" % (psutil.virtual_memory().total / 2**30))




def distance(data,lat,lng,idx):
    fLat = np.radians(data.LocationLat)
    fLon = np.radians(data.LocationLng)
    sLat = np.radians(lat)
    sLon = np.radians(lng)
    R = 3958.7564 #mi
    #R = 6371000.0 #meters
    #R = 6371.0 #km
    
    dLon = sLon - fLon
    dLat = sLat - fLat
    a = np.sin(dLat/2.0)**2 + (np.cos(fLat) * np.cos(sLat) * np.power(np.sin(dLon/2.0), 2))
    
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0 - a))
    data['dis2event_'+str(idx)] =  R * c
    return data

class WithExtraArgs(object):
    def __init__(self, func, **args):
        self.func = func
        self.args = args
    def __call__(self, df):
        return self.func(df, **self.args)
def parjob_long_event_group_W(data,filepath,key_ds):
    process_name = str(multiprocessing.current_process())
    id = int(process_name.split(',')[0].split('-')[1])
    print("process ",id," started")
    
    ds = pd.read_hdf(filepath,key=key_ds)
    print ("data set is loaded data size is ",ds.shape[0])
    traffic_events = ds[ds.Type!='W']
    re_list=[]
    total = data.shape[0]
    counter=0
    event_duration_week_offset = 60*24*60 
    print ("partial long event for process ",id," is ",data.shape[0])
    
    out_dict={}
    for idx,long_event in data.iterrows():
        temp_df = traffic_events[(traffic_events.AirportCode == long_event.AirportCode) & 
                                 ((traffic_events.StartTime >= long_event.StartTime- 
                                     pd.Timedelta(event_duration_week_offset, unit='D')) & 
                                (traffic_events.EndTime <= long_event.EndTime+
                                      pd.Timedelta(event_duration_week_offset, unit='D')))]

        out_dict[idx] = temp_df.index
        counter+=1
        if counter%100==0:
            print ("process ",id, counter,"/",total, "long event proccesed ", datetime.datetime.now().time())
    f = open('dict_files/W_'+'split_4_'+str(id)+'.pkl',"wb")
    pickle.dump(out_dict,f)
    f.close()
    return True #re_list
    
def applyParallel_list(pool,data, func, kwargs):
    data_split = np.array_split(data,partitions)
    data_tag =pool.map(WithExtraArgs(func, **kwargs), data_split)
    return data_tag

# %%
cores = 8#cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

# %%
import os, glob

path = "dict_files/"
dirpath = os.getcwd()
dirpath+='/'+path
for filename in glob.glob(os.path.join(dirpath, 'W_split_4*')):
    os.remove(filename)

# %%
#effective_days_list=[900,800,700,600]#,500,400,300]
#effective_days_list=[500,400]#,

    
effective_days_list=[300]
for effective_days in effective_days_list:
    print ("generating long event list for ",effective_days)
    long_events_ = pd.read_hdf('../../LG.h5',key='W_split_3')
    print ("long event size is ",long_events_.shape[0])
    
    subset_df =  long_events_[long_events_.Type == 'W']
    print ("weather long events size is ",subset_df.shape[0])
    
    pool_w = Pool(cores)
    Weather_list = applyParallel_list(pool_w,subset_df,parjob_long_event_group_W,{'filepath':'../../data_set_.h5','key_ds':'DS_'+str(effective_days)})
    pool_w.close()
    pool_w.join()
    print ("done with weather set")
    print ("*"*80)
    print_memory_usage()
    #np.save("event_list_45_w"+str(effective_days),Weather_list)
# Out:
# generating long event list for  300
# long event size is  24023
# weather long events size is  24023
# process  1  started
# process  2  started
# process  3  started
# process  4  started
# process  5  started
# process  6  started
# process  7  started
# process  8  started
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# data set is loaded data size is  15192678
# partial long event for process  8  is  3002
# partial long event for process  6  is  3003
# partial long event for process  1  is  3003
# data set is loaded data size is  15192678
# partial long event for process  3  is  3003
# partial long event for process  2  is  3003
# partial long event for process  5  is  3003
# data set is loaded data size is  15192678
# partial long event for process  7  is  3003
# partial long event for process  4  is  3003
# process  8 100 / 3002 long event proccesed  20:52:08.606358
# process  2 100 / 3003 long event proccesed  20:52:09.305321
# process  5 100 / 3003 long event proccesed  20:52:10.201073
# process  6 100 / 3003 long event proccesed  20:52:10.433353
# process  3 100 / 3003 long event proccesed  20:52:10.805193
# process  1 100 / 3003 long event proccesed  20:52:10.970709
# process  7 100 / 3003 long event proccesed  20:52:11.772952
# process  4 100 / 3003 long event proccesed  20:52:14.951570
# process  8 200 / 3002 long event proccesed  20:53:50.351133
# process  2 200 / 3003 long event proccesed  20:53:51.047476
# process  5 200 / 3003 long event proccesed  20:53:52.002558
# process  7 200 / 3003 long event proccesed  20:53:53.321851
# process  6 200 / 3003 long event proccesed  20:53:53.451007
# process  3 200 / 3003 long event proccesed  20:53:53.950349
# process  1 200 / 3003 long event proccesed  20:53:54.590825
# process  4 200 / 3003 long event proccesed  20:53:58.390184
# process  8 300 / 3002 long event proccesed  20:55:32.075066
# process  2 300 / 3003 long event proccesed  20:55:32.770523
# process  5 300 / 3003 long event proccesed  20:55:33.754994
# process  7 300 / 3003 long event proccesed  20:55:34.813867
# process  6 300 / 3003 long event proccesed  20:55:36.668225
# process  3 300 / 3003 long event proccesed  20:55:36.947106
# process  1 300 / 3003 long event proccesed  20:55:37.991992
# process  4 300 / 3003 long event proccesed  20:55:41.234268
# process  8 400 / 3002 long event proccesed  20:57:13.782442
# process  2 400 / 3003 long event proccesed  20:57:14.634389
# process  5 400 / 3003 long event proccesed  20:57:15.516146
# process  7 400 / 3003 long event proccesed  20:57:16.757129
# process  6 400 / 3003 long event proccesed  20:57:19.860761
# process  3 400 / 3003 long event proccesed  20:57:20.172110
# process  1 400 / 3003 long event proccesed  20:57:21.569770
# process  4 400 / 3003 long event proccesed  20:57:24.750795
# process  8 500 / 3002 long event proccesed  20:58:55.484968
# process  2 500 / 3003 long event proccesed  20:58:56.036163
# process  5 500 / 3003 long event proccesed  20:58:56.993050
# process  7 500 / 3003 long event proccesed  20:58:58.281864
# process  3 500 / 3003 long event proccesed  20:59:03.061516
# process  6 500 / 3003 long event proccesed  20:59:03.113363
# process  1 500 / 3003 long event proccesed  20:59:05.184427
# process  4 500 / 3003 long event proccesed  20:59:07.611340
# process  8 600 / 3002 long event proccesed  21:00:37.211037
# process  2 600 / 3003 long event proccesed  21:00:38.197829
# process  5 600 / 3003 long event proccesed  21:00:39.267349
# process  7 600 / 3003 long event proccesed  21:00:40.291886
# process  3 600 / 3003 long event proccesed  21:00:45.924576
# process  6 600 / 3003 long event proccesed  21:00:46.697733
# process  1 600 / 3003 long event proccesed  21:00:48.773835
# process  4 600 / 3003 long event proccesed  21:00:50.773565
# process  8 700 / 3002 long event proccesed  21:02:19.338160
# process  2 700 / 3003 long event proccesed  21:02:19.789301
# process  5 700 / 3003 long event proccesed  21:02:21.297805
# process  7 700 / 3003 long event proccesed  21:02:22.121973
# process  3 700 / 3003 long event proccesed  21:02:29.232823
# process  6 700 / 3003 long event proccesed  21:02:30.434519
# process  1 700 / 3003 long event proccesed  21:02:32.608164
# process  4 700 / 3003 long event proccesed  21:02:33.710443
# process  2 800 / 3003 long event proccesed  21:04:01.067550
# process  8 800 / 3002 long event proccesed  21:04:01.114852
# process  5 800 / 3003 long event proccesed  21:04:02.767470
# process  7 800 / 3003 long event proccesed  21:04:03.392646
# process  3 800 / 3003 long event proccesed  21:04:12.233148
# process  6 800 / 3003 long event proccesed  21:04:13.787386
# process  1 800 / 3003 long event proccesed  21:04:15.862834
# process  4 800 / 3003 long event proccesed  21:04:16.937401
# process  2 900 / 3003 long event proccesed  21:05:42.583274
# process  8 900 / 3002 long event proccesed  21:05:43.025598
# process  5 900 / 3003 long event proccesed  21:05:44.294427
# process  7 900 / 3003 long event proccesed  21:05:44.919318
# process  3 900 / 3003 long event proccesed  21:05:55.309577
# process  6 900 / 3003 long event proccesed  21:05:57.153375
# process  1 900 / 3003 long event proccesed  21:05:59.470136
# process  4 900 / 3003 long event proccesed  21:06:00.064172
# process  2 1000 / 3003 long event proccesed  21:07:23.904265
# process  8 1000 / 3002 long event proccesed  21:07:24.701142
# process  5 1000 / 3003 long event proccesed  21:07:25.899118
# process  7 1000 / 3003 long event proccesed  21:07:26.363628
# process  3 1000 / 3003 long event proccesed  21:07:38.583362
# process  6 1000 / 3003 long event proccesed  21:07:40.784962
# process  1 1000 / 3003 long event proccesed  21:07:42.828421
# process  4 1000 / 3003 long event proccesed  21:07:43.023802
# process  2 1100 / 3003 long event proccesed  21:09:05.534058
# process  8 1100 / 3002 long event proccesed  21:09:06.712783
# process  7 1100 / 3003 long event proccesed  21:09:07.814435
# process  5 1100 / 3003 long event proccesed  21:09:07.836388
# process  3 1100 / 3003 long event proccesed  21:09:21.414869
# process  6 1100 / 3003 long event proccesed  21:09:24.127209
# process  1 1100 / 3003 long event proccesed  21:09:25.895879
# process  4 1100 / 3003 long event proccesed  21:09:26.183019
# process  4 2400 / 3003 long event proccesed  21:31:47.574833
# process  2 2500 / 3003 long event proccesed  21:32:48.607788
# process  7 2500 / 3003 long event proccesed  21:32:49.774746
# process  8 2500 / 3002 long event proccesed  21:32:52.143818
# process  5 2500 / 3003 long event proccesed  21:32:54.512097
# process  3 2500 / 3003 long event proccesed  21:33:23.731270
# process  6 2500 / 3003 long event proccesed  21:33:29.714931
# process  1 2500 / 3003 long event proccesed  21:33:30.006853
# process  4 2500 / 3003 long event proccesed  21:33:30.544288
# process  2 2600 / 3003 long event proccesed  21:34:30.343392
# process  7 2600 / 3003 long event proccesed  21:34:31.423329
# process  8 2600 / 3002 long event proccesed  21:34:33.644585
# process  5 2600 / 3003 long event proccesed  21:34:36.216291
# process  3 2600 / 3003 long event proccesed  21:35:06.595311
# process  6 2600 / 3003 long event proccesed  21:35:12.827879
# process  1 2600 / 3003 long event proccesed  21:35:12.937797
# process  4 2600 / 3003 long event proccesed  21:35:13.407520
# process  2 2700 / 3003 long event proccesed  21:36:12.023036
# process  7 2700 / 3003 long event proccesed  21:36:13.095918
# process  8 2700 / 3002 long event proccesed  21:36:15.291151
# process  5 2700 / 3003 long event proccesed  21:36:17.916325
# process  3 2700 / 3003 long event proccesed  21:36:49.799560
# process  6 2700 / 3003 long event proccesed  21:36:55.965109
# process  1 2700 / 3003 long event proccesed  21:36:56.063491
# process  4 2700 / 3003 long event proccesed  21:36:56.359892
# process  2 2800 / 3003 long event proccesed  21:37:53.886179
# process  7 2800 / 3003 long event proccesed  21:37:54.364745
# process  8 2800 / 3002 long event proccesed  21:37:56.955081
# process  5 2800 / 3003 long event proccesed  21:37:59.836634
# process  3 2800 / 3003 long event proccesed  21:38:32.407497
# process  6 2800 / 3003 long event proccesed  21:38:38.411792
# process  1 2800 / 3003 long event proccesed  21:38:38.692898
# process  4 2800 / 3003 long event proccesed  21:38:38.828589
# process  2 2900 / 3003 long event proccesed  21:39:37.293068
# process  7 2900 / 3003 long event proccesed  21:39:37.301226
# process  8 2900 / 3002 long event proccesed  21:39:39.959849
# process  5 2900 / 3003 long event proccesed  21:39:42.886001
# process  3 2900 / 3003 long event proccesed  21:40:13.709499
# process  6 2900 / 3003 long event proccesed  21:40:19.632340
# process  1 2900 / 3003 long event proccesed  21:40:20.305832
# process  4 2900 / 3003 long event proccesed  21:40:20.399020
# process  7 3000 / 3003 long event proccesed  21:41:20.423509
# process  2 3000 / 3003 long event proccesed  21:41:20.688441
# process  8 3000 / 3002 long event proccesed  21:41:23.363790
# process  5 3000 / 3003 long event proccesed  21:41:26.492524
# process  3 3000 / 3003 long event proccesed  21:41:54.386382
# process  6 3000 / 3003 long event proccesed  21:42:00.525967
# process  4 3000 / 3003 long event proccesed  21:42:00.923269
# process  1 3000 / 3003 long event proccesed  21:42:02.179942
# done with weather set
# ********************************************************************************
# memory log:
#  0.11 GB (RSS)
#  1.08 GB (VMS)
#  3.42 GB (Used)
# 121.52 GB (Available)
# 125.81 GB (Total)
